# %% [markdown]
# # Fundamentos de Banco de Dados
# **PPCA/UNB**
#
# ---
#
# **Trabalho final - Licitações do Governo Federal**
# **Professor**: Márcio de Carvalho Victorino
# **Alunos**: Andreia Queiroz Correia Dummar (241134680) e Denard Costa Soares (241130467)
# **Data da Entrega**: 21/02/2025
# **Github**: https://github.com/denards/fornecedores-contratos
#
# ---
#
# **Fontes:**
#
# 1. **Portal da Transparência** (Dados de licitações)
#    - [https://portaldatransparencia.gov.br/download-de-dados/licitacoes](https://portaldatransparencia.gov.br/download-de-dados/licitacoes)
#
# 2. **Compras Governamentais**
#    - **Órgãos**: [https://compras.dados.gov.br/licitacoes/v1/orgaos.json](https://compras.dados.gov.br/licitacoes/v1/orgaos.json)
#    - **Modalidades de Licitação**: [https://compras.dados.gov.br/licitacoes/v1/modalidades_licitacao.json](https://compras.dados.gov.br/licitacoes/v1/modalidades_licitacao.json)
#
#
# ---

# %% [markdown]
# ## 1) Bibliotecas
# ---

# %%
# Bibliotecas para manipulação de dados
import os
import numpy as np
import pandas as pd

# Bibliotecas para requisições HTTP
import requests

# Bibliotecas para conexão com banco de dados
import psycopg2
from sqlalchemy import create_engine
from urllib.parse import urlparse

# %%
# Configurações do PostgreSQL
DB_HOST = "localhost"  
DB_PORT = "5432"       
DB_NAME = "licitacoes_contratos"  
DB_USER = "postgres"
DB_PASS = "1234"

# Outras configuracoes
diretorio = "Dados"

# %% [markdown]
# ---
# ## 2) Funções
# ---

# %%
def verificar_tamanho_colunas(df):
    """
    Verifica o tamanho máximo dos valores em cada coluna de um DataFrame.

    Parâmetros:
    - df (pd.DataFrame): DataFrame a ser analisado.

    Retorna:
    - pd.DataFrame: DataFrame com o nome da coluna e o tamanho máximo dos valores.
    """
    tamanhos = {col: df[col].astype(str).map(len).max() for col in df.columns}
    df_tamanhos = pd.DataFrame(list(tamanhos.items()), columns=['Coluna', 'Tamanho Máximo'])
    
    return df_tamanhos

# %%
def ler_csv(arquivo, encoding="ISO-8859-1"):
    """
    Lê um arquivo CSV de um diretório específico e retorna um DataFrame.
    
    Parâmetros:
        nome_arquivo (str): Nome do arquivo CSV (ex: "202401_Licitação.csv").
        diretorio (str): Diretório onde o arquivo está localizado (padrão: "Dados").
    
    Retorna:
        pd.DataFrame: DataFrame contendo os dados do CSV.
    """
     
    # Ler o CSV com delimitador ";" e codificação ISO-8859-1
    df = pd.read_csv(arquivo, delimiter=";", encoding="ISO-8859-1", low_memory=False)
    return df

# %%
def ler_arquivo_csv(arquivo, encoding="ISO-8859-1"):

    df_licitacao = ler_csv(arquivo, encoding)
    
    # Extraindo ano e mês do nome do arquivo
    nome_arquivo = os.path.basename(arquivo)
    ano = nome_arquivo[:4]
    mes = nome_arquivo[4:6]
    
    # Adicionando colunas de ano e mês
    df_licitacao['ano'] = ano
    df_licitacao['mes'] = mes
    
    return df_licitacao

# %%
# Função para processar o diretório e carregar os arquivos CSV
def processar_diretorio(diretorio, chave, encoding="ISO-8859-1"):
    """
    Processa um diretório e concatena arquivos CSV que terminam com '_chave.csv'.

    Parâmetros:
    - diretorio (str): Caminho do diretório onde estão os arquivos CSV.
    - chave (str): Identificador para selecionar arquivos que terminam com '_chave.csv'.
    - encoding (str, opcional): Encoding usado para ler os arquivos (padrão: 'ISO-8859-1').

    Retorna:
    - pd.DataFrame: DataFrame contendo a concatenação de todos os arquivos encontrados.
    """
    # Listar arquivos que terminam com "_chave.csv"
    arquivos = [os.path.join(diretorio, f) for f in os.listdir(diretorio) if f.endswith(f"_{chave}.csv")]

    if not arquivos:
        print(f"⚠️ Nenhum arquivo encontrado em '{diretorio}' com a chave '{chave}'.")
        return pd.DataFrame()  # Retorna um DataFrame vazio se não houver arquivos

    # Passar corretamente os arquivos para a função `ler_arquivo_csv`
    dataframes = [ler_arquivo_csv(arquivo, encoding) for arquivo in arquivos]

    # Remover arquivos que falharam ao carregar (None)
    dataframes = [df for df in dataframes if df is not None]

    if not dataframes:
        print("❌ Nenhum arquivo válido foi carregado.")
        return pd.DataFrame()

    df_final = pd.concat(dataframes, ignore_index=True)

    print(f"✅ {len(dataframes)} arquivos processados e {df_final.shape[0]} registros carregados.")
    
    return df_final

# %%
def LerJson(aURL, aitem):
    
    try:
        
        erro = False
        df_link = pd.DataFrame()
        df_ret= pd.DataFrame()
        response = requests.get(aURL, timeout=5)
    
        if response.status_code == 200:

            dictr = response.json()

            # Recupera o nome da próxima pagina
            recs = dictr['_links']
            df_link = pd.json_normalize(recs)

            # Recupera os contratos
            recs = dictr['_embedded']
            df_ret = pd.json_normalize(recs, record_path=[aitem])
            
        else:
             erro  = True

        response.close()
        
    except Exception as e:
    # do whatever you want
        erro  = True
        
    return [df_link, df_ret, erro]

# %%
def obter_dados_json(url, chave):

    parsed_url = urlparse(url)
    url_base = f"{parsed_url.scheme}://{parsed_url.netloc}"

    df_final = pd.DataFrame()
    df_dados = pd.DataFrame()
    
    ret = LerJson(url, chave)
    df_pagina = ret[0]
    df_dados = pd.concat([df_dados, ret[1]])

    contador = 0
    maximo = 100
    while (contador < maximo):
        
        if df_pagina.shape[0] == 1:
            if df_pagina.columns.isin(['next.href']).any():
                print(url_base + df_pagina.loc[0,'next.href'])
                ret = LerJson(url_base + df_pagina.loc[0,'next.href'], chave) 
                if ret[2] == False:
                    df_pagina = ret[0]
                    df_dados = pd.concat([df_dados, ret[1]])
            else:
                break
        else:
            break
        contador = contador + 1
        
    return df_dados

# %%
def inserir_dados_postgresql(df, tabela, host, porta, banco, usuario, senha, excluir_antes=False, batch_size=10000):
    """
    Insere registros de um DataFrame no PostgreSQL em lotes de 1000 registros.

    Parâmetros:
    - df (pd.DataFrame): DataFrame com os dados a serem inseridos.
    - tabela (str): Nome da tabela de destino no PostgreSQL.
    - host (str): Endereço do servidor PostgreSQL.
    - porta (str): Porta do PostgreSQL.
    - banco (str): Nome do banco de dados.
    - usuario (str): Usuário do banco de dados.
    - senha (str): Senha do banco de dados.
    - excluir_antes (bool, opcional): Se True, exclui todos os registros antes da inserção (default: False).
    - batch_size (int, opcional): Número de registros inseridos por vez (default: 1000).

    Retorna:
    - str: Mensagem indicando o sucesso ou erro da operação.
    """
    try:
        # Criando a string de conexão
        conn_string = f'postgresql+psycopg2://{usuario}:{senha}@{host}:{porta}/{banco}?client_encoding=utf8'
        engine = create_engine(conn_string)

        # Conectar ao banco para exclusão, se necessário
        if excluir_antes:
            with psycopg2.connect(dbname=banco, user=usuario, password=senha, host=host, port=porta) as conn:
                with conn.cursor() as cursor:
                    cursor.execute(f"DELETE FROM {tabela};")
                    conn.commit()
                    print(f"🗑️ Todos os registros da tabela '{tabela}' foram excluídos.")

        # Substituir valores NaT e NaN por None (NULL no PostgreSQL)
        df = df.where(pd.notna(df), None)

        # Garantir que apenas colunas textuais sejam convertidas para string corretamente
        for col in df.select_dtypes(include=["object"]).columns:
            df[col] = df[col].apply(lambda x: str(x) if x is not None else None)

        # Contador para acompanhar a inserção por lotes
        total_registros = len(df)
        print(f"📊 Total de registros a serem inseridos: {total_registros}")

        for i in range(0, total_registros, batch_size):
            df_lote = df.iloc[i:i+batch_size]  # Pegando um lote de 1000 registros
            df_lote.to_sql(tabela, engine, if_exists='append', index=False, method='multi')
            print(f"✅ Inseridos {min(i+batch_size, total_registros)}/{total_registros} registros...")

        return "✅ Registros inseridos com sucesso!"

    except psycopg2.Error as e:
        return f"❌ Erro ao conectar ou executar query no PostgreSQL: {e}"
    
    except Exception as e:
        return f"❌ Erro ao inserir dados: {e}"

# %%
def ler_tabela_postgresql(tabela, host, porta, banco, usuario, senha):
    """
    Lê uma tabela do PostgreSQL e retorna como um DataFrame Pandas.

    Parâmetros:
    - tabela (str): Nome da tabela a ser lida.
    - host (str): Endereço do servidor PostgreSQL (exemplo: "localhost").
    - porta (str): Porta do PostgreSQL (exemplo: "5432").
    - banco (str): Nome do banco de dados.
    - usuario (str): Usuário do banco de dados.
    - senha (str): Senha do banco de dados.

    Retorna:
    - pd.DataFrame: DataFrame Pandas contendo os dados da tabela.
    """
    try:
        # Criando a string de conexão com PostgreSQL
        conn_string = f'postgresql+psycopg2://{usuario}:{senha}@{host}:{porta}/{banco}'
        engine = create_engine(conn_string)

        # Lendo a tabela para um DataFrame
        query = f"SELECT * FROM {tabela}"
        df = pd.read_sql(query, engine)

        print(f"✅ Tabela '{tabela}' carregada com sucesso! {df.shape[0]} registros encontrados.")
        return df

    except Exception as e:
        print(f"❌ Erro ao ler a tabela '{tabela}': {e}")
        return None

# %% [markdown]
# ---
# ## 3) ETL
# ---

# %% [markdown]
# ### 3.1) ETL ÓRGÃO
# ---

# %%
# Chamando a função
# url = "https://compras.dados.gov.br/licitacoes/v1/orgaos.json"
# chave = "Orgaos"

arquivo = "orgaos.parquet"

# df_orgaos = obter_dados_json(url, chave)

# df_orgaos.to_parquet(f"{diretorio}/{arquivo}", engine="pyarrow", index=False)

# Execucoes posteriores, utiliza o arquivo salvo
df_orgaos = pd.read_parquet(f"{diretorio}/{arquivo}", engine="fastparquet")

# Exibindo as primeiras linhas
df_orgaos.head(100)
# Out:
#     codigo                                           nome  codigo_tipo_adm  \
# 0     1000                           CAMARA DOS DEPUTADOS                1
# 1     1901         FUNDO ROTATIVO DA CAMARA DOS DEPUTADOS                7
# 2     2000                                 SENADO FEDERAL                1
# 3     2001               FUNDO ESPECIAL DO SENADO FEDERAL                7
# 4     2002                         SENADO FEDERAL/FUNSEEP                7
# ..     ...                                            ...              ...
# 95   22500   CIA.DE ENTREPOSTOS E ARMAZENS GER.DE S.PAULO                2
# 96   22801  COMIS.EXEC.DO PLANO DA LAVOURA CACAUEIRA/MAPA                1
# 97   22802        INSTITUTO NACIONAL DE METEOROLOGIA/MAPA                1
# 98   22803    SECRETARIA NAC. DE DEFESA AGROPECUARIA/MAPA                1
# 99   22804     SUBSECRETARIA DE PLANEJ.,ORCAM.E ADM./MAPA                1
#
#    codigo_tipo_esfera  codigo_tipo_poder  ativo            _links.self.href  \
# 0             Federal                  1   True   /licitacoes/id/orgao/1000
# 1                None                  1   True   /licitacoes/id/orgao/1901
# 2                None                  1   True   /licitacoes/id/orgao/2000
# 3                None                  1   True   /licitacoes/id/orgao/2001
# 4                None                  1   True   /licitacoes/id/orgao/2002
# ..                ...                ...    ...                         ...
# 95            Federal                  0   True  /licitacoes/id/orgao/22500
# 96               None                  0   True  /licitacoes/id/orgao/22801
# 97               None                  0   True  /licitacoes/id/orgao/22802
# 98               None                  0   True  /licitacoes/id/orgao/22803
# 99               None                  0   True  /licitacoes/id/orgao/22804
#
#                                     _links.self.title  \
# 0                    Órgão 1000: CAMARA DOS DEPUTADOS
# 1   Órgão 1901: FUNDO ROTATIVO DA CAMARA DOS DEPUT...
# 2                          Órgão 2000: SENADO FEDERAL
# 3        Órgão 2001: FUNDO ESPECIAL DO SENADO FEDERAL
# 4                  Órgão 2002: SENADO FEDERAL/FUNSEEP
# ..                                                ...
# 95  Órgão 22500: CIA.DE ENTREPOSTOS E ARMAZENS GER...
# 96  Órgão 22801: COMIS.EXEC.DO PLANO DA LAVOURA CA...
# 97  Órgão 22802: INSTITUTO NACIONAL DE METEOROLOGI...
# 98  Órgão 22803: SECRETARIA NAC. DE DEFESA AGROPEC...
# 99  Órgão 22804: SUBSECRETARIA DE PLANEJ.,ORCAM.E ...
#
#                             _links.api_orcamento.href  \
# 0   http://orcamento.dados.gov.br/doc/2014/Orgao/1000
# 1   http://orcamento.dados.gov.br/doc/2014/Orgao/1901
# 2   http://orcamento.dados.gov.br/doc/2014/Orgao/2000
# 3   http://orcamento.dados.gov.br/doc/2014/Orgao/2001
# 4   http://orcamento.dados.gov.br/doc/2014/Orgao/2002
# ..                                                ...
# 95  http://orcamento.dados.gov.br/doc/2014/Orgao/2...
# 96  http://orcamento.dados.gov.br/doc/2014/Orgao/2...
# 97  http://orcamento.dados.gov.br/doc/2014/Orgao/2...
# 98  http://orcamento.dados.gov.br/doc/2014/Orgao/2...
# 99  http://orcamento.dados.gov.br/doc/2014/Orgao/2...
#
#                            _links.api_orcamento.title  \
# 0   Este órgão orçamentário sob o ponto de vista d...
# 1   Este órgão orçamentário sob o ponto de vista d...
# 2   Este órgão orçamentário sob o ponto de vista d...
# 3   Este órgão orçamentário sob o ponto de vista d...
# 4   Este órgão orçamentário sob o ponto de vista d...
# ..                                                ...
# 95  Este órgão orçamentário sob o ponto de vista d...
# 96  Este órgão orçamentário sob o ponto de vista d...
# 97  Este órgão orçamentário sob o ponto de vista d...
# 98  Este órgão orçamentário sob o ponto de vista d...
# 99  Este órgão orçamentário sob o ponto de vista d...
#
#                                _links.api_siconv.href  \
# 0   http://api.convenios.gov.br/siconv/dados/orgao...
# 1   http://api.convenios.gov.br/siconv/dados/orgao...
# 2   http://api.convenios.gov.br/siconv/dados/orgao...
# 3   http://api.convenios.gov.br/siconv/dados/orgao...
# 4   http://api.convenios.gov.br/siconv/dados/orgao...
# ..                                                ...
# 95  http://api.convenios.gov.br/siconv/dados/orgao...
# 96  http://api.convenios.gov.br/siconv/dados/orgao...
# 97  http://api.convenios.gov.br/siconv/dados/orgao...
# 98  http://api.convenios.gov.br/siconv/dados/orgao...
# 99  http://api.convenios.gov.br/siconv/dados/orgao...
#
#                               _links.api_siconv.title  \
# 0   Este órgão orçamentário sob o ponto de vista d...
# 1   Este órgão orçamentário sob o ponto de vista d...
# 2   Este órgão orçamentário sob o ponto de vista d...
# 3   Este órgão orçamentário sob o ponto de vista d...
# 4   Este órgão orçamentário sob o ponto de vista d...
# ..                                                ...
# 95  Este órgão orçamentário sob o ponto de vista d...
# 96  Este órgão orçamentário sob o ponto de vista d...
# 97  Este órgão orçamentário sob o ponto de vista d...
# 98  Este órgão orçamentário sob o ponto de vista d...
# 99  Este órgão orçamentário sob o ponto de vista d...
#
#                   _links.ocorrencia_fornecedores.href  \
# 0   /fornecedores/v1/ocorrencias_fornecedores?id_o...
# 1   /fornecedores/v1/ocorrencias_fornecedores?id_o...
# 2   /fornecedores/v1/ocorrencias_fornecedores?id_o...
# 3   /fornecedores/v1/ocorrencias_fornecedores?id_o...
# 4   /fornecedores/v1/ocorrencias_fornecedores?id_o...
# ..                                                ...
# 95  /fornecedores/v1/ocorrencias_fornecedores?id_o...
# 96  /fornecedores/v1/ocorrencias_fornecedores?id_o...
# 97  /fornecedores/v1/ocorrencias_fornecedores?id_o...
# 98  /fornecedores/v1/ocorrencias_fornecedores?id_o...
# 99  /fornecedores/v1/ocorrencias_fornecedores?id_o...
#
#     _links.ocorrencia_fornecedores.title                    _links.uasgs.href  \
# 0   Ocorrências aplicadas por este órgão   /licitacoes/v1/uasgs?id_orgao=1000
# 1   Ocorrências aplicadas por este órgão   /licitacoes/v1/uasgs?id_orgao=1901
# 2   Ocorrências aplicadas por este órgão   /licitacoes/v1/uasgs?id_orgao=2000
# 3   Ocorrências aplicadas por este órgão   /licitacoes/v1/uasgs?id_orgao=2001
# 4   Ocorrências aplicadas por este órgão   /licitacoes/v1/uasgs?id_orgao=2002
# ..                                   ...                                  ...
# 95  Ocorrências aplicadas por este órgão  /licitacoes/v1/uasgs?id_orgao=22500
# 96  Ocorrências aplicadas por este órgão  /licitacoes/v1/uasgs?id_orgao=22801
# 97  Ocorrências aplicadas por este órgão  /licitacoes/v1/uasgs?id_orgao=22802
# 98  Ocorrências aplicadas por este órgão  /licitacoes/v1/uasgs?id_orgao=22803
# 99  Ocorrências aplicadas por este órgão  /licitacoes/v1/uasgs?id_orgao=22804
#
#                _links.uasgs.title
# 0   UASGs associadas a este Órgão
# 1   UASGs associadas a este Órgão
# 2   UASGs associadas a este Órgão
# 3   UASGs associadas a este Órgão
# 4   UASGs associadas a este Órgão
# ..                            ...
# 95  UASGs associadas a este Órgão
# 96  UASGs associadas a este Órgão
# 97  UASGs associadas a este Órgão
# 98  UASGs associadas a este Órgão
# 99  UASGs associadas a este Órgão
#
# [100 rows x 16 columns]

# %%
df_orgaos.shape
# Out:
# (9095, 16)

# %%
df_orgaos_tipo_esfera = df_orgaos.drop_duplicates(subset=['codigo_tipo_esfera'])[['codigo_tipo_esfera']].reset_index(drop=True)
df_orgaos_tipo_esfera.head(100)
# Out:
#   codigo_tipo_esfera
# 0            Federal
# 1               None
# 2           Estadual
# 3          Municipal

# %%
df_orgaos_tipo_esfera = df_orgaos.drop_duplicates(subset=['ativo'])[['ativo']].reset_index(drop=True)
df_orgaos_tipo_esfera.head(100)
# Out:
#    ativo
# 0   True
# 1  False

# %%
# Selecionar colunas específicas
df_orgaos_carga = df_orgaos[['codigo', 'nome', 'codigo_tipo_adm', 'codigo_tipo_esfera', 'codigo_tipo_poder', 'ativo']].copy()

df_orgaos_carga["ativo"] = df_orgaos_carga["ativo"].astype(int)

# Converter coluna "ativo" corretamente para boolean (True/False) antes da inserção
if "ativo" in df_orgaos_carga.columns:
    df_orgaos_carga["ativo"] = df_orgaos_carga["ativo"].apply(lambda x: True if x == 1 else False if x == 0 else None)

# Renomear colunas
df_orgaos_carga = df_orgaos_carga.rename(columns={
    "codigo_tipo_adm": "tipo_adm",
    "codigo_tipo_esfera": "tipo_esfera",
    "codigo_tipo_poder": "tipo_poder"
})

# Exibir as primeiras linhas
df_orgaos_carga.head()
# Out:
#    codigo                                    nome  tipo_adm tipo_esfera  \
# 0    1000                    CAMARA DOS DEPUTADOS         1     Federal
# 1    1901  FUNDO ROTATIVO DA CAMARA DOS DEPUTADOS         7        None
# 2    2000                          SENADO FEDERAL         1        None
# 3    2001        FUNDO ESPECIAL DO SENADO FEDERAL         7        None
# 4    2002                  SENADO FEDERAL/FUNSEEP         7        None
#
#    tipo_poder  ativo
# 0           1   True
# 1           1   True
# 2           1   True
# 3           1   True
# 4           1   True

# %%
df_tamanhos = verificar_tamanho_colunas(df_orgaos_carga)

print(df_tamanhos)
# Out:
#         Coluna  Tamanho Máximo
# 0       codigo               5
# 1         nome              45
# 2     tipo_adm               2
# 3  tipo_esfera               9
# 4   tipo_poder               1
# 5        ativo               5

# %%
# Insere dados de modalidade
# Chamando a função para inserir os dados
resultado = inserir_dados_postgresql(df_orgaos_carga, "orgao", DB_HOST, DB_PORT, DB_NAME, DB_USER, DB_PASS, excluir_antes=True)

# Exibindo o resultado
print(resultado)
# Out:
# 🗑️ Todos os registros da tabela 'orgao' foram excluídos.
# 📊 Total de registros a serem inseridos: 9095
# ✅ Inseridos 9095/9095 registros...
# ✅ Registros inseridos com sucesso!

# %% [markdown]
# ---
# ### 3.2) ETL Modalidade
# ---

# %%
# Chamando a função
# url = "https://compras.dados.gov.br/licitacoes/v1/modalidades_licitacao.json"
# chave = "ModalidadesLicitacao"

arquivo = "modalidade.parquet"

# df_modalidades = obter_dados_json(url, chave)

# df_modalidades.to_parquet(f"{diretorio}/{arquivo}", engine="pyarrow", index=False)

# Execucoes posteriores, utiliza o arquivo salvo
df_modalidades = pd.read_parquet(f"{diretorio}/{arquivo}", engine="fastparquet")

# Exibindo as primeiras linhas
df_modalidades.head(100)
# Out:
#     codigo                                          descricao  \
# 0        1  CONVITE                                       ...
# 1        2  TOMADA DE PREÇOS                              ...
# 2        3  CONCORRÊNCIA                                  ...
# 3        4  CONCORRÊNCIA INTERNACIONAL                    ...
# 4        5  PREGÃO                                        ...
# 5        6  DISPENSA DE LICITAÇÃO                         ...
# 6        7  INEXIGIBILIDADE DE LICITAÇÃO                  ...
# 7       20  CONCURSO                                      ...
# 8       22  TOMADA DE PREÇOS POR TÉCNICA E PREÇO          ...
# 9       33  CONCORRÊNCIA POR TÉCNICA E PREÇO              ...
# 10      44  CONCORRÊNCIA INTERNACIONAL POR TÉCNICA E PREÇO...
#
#                           _links.self.href  \
# 0    /licitacoes/id/modalidade_licitacao/1
# 1    /licitacoes/id/modalidade_licitacao/2
# 2    /licitacoes/id/modalidade_licitacao/3
# 3    /licitacoes/id/modalidade_licitacao/4
# 4    /licitacoes/id/modalidade_licitacao/5
# 5    /licitacoes/id/modalidade_licitacao/6
# 6    /licitacoes/id/modalidade_licitacao/7
# 7   /licitacoes/id/modalidade_licitacao/20
# 8   /licitacoes/id/modalidade_licitacao/22
# 9   /licitacoes/id/modalidade_licitacao/33
# 10  /licitacoes/id/modalidade_licitacao/44
#
#                                     _links.self.title  \
# 0   Modalidade da Licitação 1: CONVITE            ...
# 1   Modalidade da Licitação 2: TOMADA DE PREÇOS   ...
# 2   Modalidade da Licitação 3: CONCORRÊNCIA       ...
# 3   Modalidade da Licitação 4: CONCORRÊNCIA INTERN...
# 4   Modalidade da Licitação 5: PREGÃO             ...
# 5   Modalidade da Licitação 6: DISPENSA DE LICITAÇ...
# 6   Modalidade da Licitação 7: INEXIGIBILIDADE DE ...
# 7   Modalidade da Licitação 20: CONCURSO          ...
# 8   Modalidade da Licitação 22: TOMADA DE PREÇOS P...
# 9   Modalidade da Licitação 33: CONCORRÊNCIA POR T...
# 10  Modalidade da Licitação 44: CONCORRÊNCIA INTER...
#
#                     _links.contratos.href  \
# 0    /contratos/v1/contratos?modalidade=1
# 1    /contratos/v1/contratos?modalidade=2
# 2    /contratos/v1/contratos?modalidade=3
# 3    /contratos/v1/contratos?modalidade=4
# 4    /contratos/v1/contratos?modalidade=5
# 5    /contratos/v1/contratos?modalidade=6
# 6    /contratos/v1/contratos?modalidade=7
# 7   /contratos/v1/contratos?modalidade=20
# 8   /contratos/v1/contratos?modalidade=22
# 9   /contratos/v1/contratos?modalidade=33
# 10  /contratos/v1/contratos?modalidade=44
#
#                                _links.contratos.title  \
# 0   Contratos até 2020 que originaram de licitaçõe...
# 1   Contratos até 2020 que originaram de licitaçõe...
# 2   Contratos até 2020 que originaram de licitaçõe...
# 3   Contratos até 2020 que originaram de licitaçõe...
# 4   Contratos até 2020 que originaram de licitaçõe...
# 5   Contratos até 2020 que originaram de licitaçõe...
# 6   Contratos até 2020 que originaram de licitaçõe...
# 7   Contratos até 2020 que originaram de licitaçõe...
# 8   Contratos até 2020 que originaram de licitaçõe...
# 9   Contratos até 2020 que originaram de licitaçõe...
# 10  Contratos até 2020 que originaram de licitaçõe...
#
#                                _links.irps.href  \
# 0    /licitacoes/v1/irps?modalidade_licitacao=1
# 1    /licitacoes/v1/irps?modalidade_licitacao=2
# 2    /licitacoes/v1/irps?modalidade_licitacao=3
# 3    /licitacoes/v1/irps?modalidade_licitacao=4
# 4    /licitacoes/v1/irps?modalidade_licitacao=5
# 5    /licitacoes/v1/irps?modalidade_licitacao=6
# 6    /licitacoes/v1/irps?modalidade_licitacao=7
# 7   /licitacoes/v1/irps?modalidade_licitacao=20
# 8   /licitacoes/v1/irps?modalidade_licitacao=22
# 9   /licitacoes/v1/irps?modalidade_licitacao=33
# 10  /licitacoes/v1/irps?modalidade_licitacao=44
#
#                                     _links.irps.title  \
# 0   IRPs que resultaram em licitações com esta mod...
# 1   IRPs que resultaram em licitações com esta mod...
# 2   IRPs que resultaram em licitações com esta mod...
# 3   IRPs que resultaram em licitações com esta mod...
# 4   IRPs que resultaram em licitações com esta mod...
# 5   IRPs que resultaram em licitações com esta mod...
# 6   IRPs que resultaram em licitações com esta mod...
# 7   IRPs que resultaram em licitações com esta mod...
# 8   IRPs que resultaram em licitações com esta mod...
# 9   IRPs que resultaram em licitações com esta mod...
# 10  IRPs que resultaram em licitações com esta mod...
#
#                      _links.licitacoes.href         _links.licitacoes.title
# 0    /licitacoes/v1/licitacoes?modalidade=1  Licitações com esta modalidade
# 1    /licitacoes/v1/licitacoes?modalidade=2  Licitações com esta modalidade
# 2    /licitacoes/v1/licitacoes?modalidade=3  Licitações com esta modalidade
# 3    /licitacoes/v1/licitacoes?modalidade=4  Licitações com esta modalidade
# 4    /licitacoes/v1/licitacoes?modalidade=5  Licitações com esta modalidade
# 5    /licitacoes/v1/licitacoes?modalidade=6  Licitações com esta modalidade
# 6    /licitacoes/v1/licitacoes?modalidade=7  Licitações com esta modalidade
# 7   /licitacoes/v1/licitacoes?modalidade=20  Licitações com esta modalidade
# 8   /licitacoes/v1/licitacoes?modalidade=22  Licitações com esta modalidade
# 9   /licitacoes/v1/licitacoes?modalidade=33  Licitações com esta modalidade
# 10  /licitacoes/v1/licitacoes?modalidade=44  Licitações com esta modalidade

# %%
df_modalidades.shape
# Out:
# (11, 10)

# %%
# Incluir no dataframe de modalidade a 9999 e 9997
nova_linha = {'codigo': 9999, 'descricao': 'Pregão - Registro de Preço'.upper(), '_links': None}
df_modalidades = pd.concat([df_modalidades, pd.DataFrame([nova_linha])], ignore_index=True)

nova_linha = {'codigo': 9997, 'descricao': 'Concorrência - Registro de Preço'.upper(), '_links': None}
df_modalidades = pd.concat([df_modalidades, pd.DataFrame([nova_linha])], ignore_index=True)

# Exibindo as linhas para verificar
df_modalidades.head(100)
# Out:
#     codigo                                          descricao  \
# 0        1  CONVITE                                       ...
# 1        2  TOMADA DE PREÇOS                              ...
# 2        3  CONCORRÊNCIA                                  ...
# 3        4  CONCORRÊNCIA INTERNACIONAL                    ...
# 4        5  PREGÃO                                        ...
# 5        6  DISPENSA DE LICITAÇÃO                         ...
# 6        7  INEXIGIBILIDADE DE LICITAÇÃO                  ...
# 7       20  CONCURSO                                      ...
# 8       22  TOMADA DE PREÇOS POR TÉCNICA E PREÇO          ...
# 9       33  CONCORRÊNCIA POR TÉCNICA E PREÇO              ...
# 10      44  CONCORRÊNCIA INTERNACIONAL POR TÉCNICA E PREÇO...
# 11    9999                         PREGÃO - REGISTRO DE PREÇO
# 12    9997                   CONCORRÊNCIA - REGISTRO DE PREÇO
#
#                           _links.self.href  \
# 0    /licitacoes/id/modalidade_licitacao/1
# 1    /licitacoes/id/modalidade_licitacao/2
# 2    /licitacoes/id/modalidade_licitacao/3
# 3    /licitacoes/id/modalidade_licitacao/4
# 4    /licitacoes/id/modalidade_licitacao/5
# 5    /licitacoes/id/modalidade_licitacao/6
# 6    /licitacoes/id/modalidade_licitacao/7
# 7   /licitacoes/id/modalidade_licitacao/20
# 8   /licitacoes/id/modalidade_licitacao/22
# 9   /licitacoes/id/modalidade_licitacao/33
# 10  /licitacoes/id/modalidade_licitacao/44
# 11                                     NaN
# 12                                     NaN
#
#                                     _links.self.title  \
# 0   Modalidade da Licitação 1: CONVITE            ...
# 1   Modalidade da Licitação 2: TOMADA DE PREÇOS   ...
# 2   Modalidade da Licitação 3: CONCORRÊNCIA       ...
# 3   Modalidade da Licitação 4: CONCORRÊNCIA INTERN...
# 4   Modalidade da Licitação 5: PREGÃO             ...
# 5   Modalidade da Licitação 6: DISPENSA DE LICITAÇ...
# 6   Modalidade da Licitação 7: INEXIGIBILIDADE DE ...
# 7   Modalidade da Licitação 20: CONCURSO          ...
# 8   Modalidade da Licitação 22: TOMADA DE PREÇOS P...
# 9   Modalidade da Licitação 33: CONCORRÊNCIA POR T...
# 10  Modalidade da Licitação 44: CONCORRÊNCIA INTER...
# 11                                                NaN
# 12                                                NaN
#
#                     _links.contratos.href  \
# 0    /contratos/v1/contratos?modalidade=1
# 1    /contratos/v1/contratos?modalidade=2
# 2    /contratos/v1/contratos?modalidade=3
# 3    /contratos/v1/contratos?modalidade=4
# 4    /contratos/v1/contratos?modalidade=5
# 5    /contratos/v1/contratos?modalidade=6
# 6    /contratos/v1/contratos?modalidade=7
# 7   /contratos/v1/contratos?modalidade=20
# 8   /contratos/v1/contratos?modalidade=22
# 9   /contratos/v1/contratos?modalidade=33
# 10  /contratos/v1/contratos?modalidade=44
# 11                                    NaN
# 12                                    NaN
#
#                                _links.contratos.title  \
# 0   Contratos até 2020 que originaram de licitaçõe...
# 1   Contratos até 2020 que originaram de licitaçõe...
# 2   Contratos até 2020 que originaram de licitaçõe...
# 3   Contratos até 2020 que originaram de licitaçõe...
# 4   Contratos até 2020 que originaram de licitaçõe...
# 5   Contratos até 2020 que originaram de licitaçõe...
# 6   Contratos até 2020 que originaram de licitaçõe...
# 7   Contratos até 2020 que originaram de licitaçõe...
# 8   Contratos até 2020 que originaram de licitaçõe...
# 9   Contratos até 2020 que originaram de licitaçõe...
# 10  Contratos até 2020 que originaram de licitaçõe...
# 11                                                NaN
# 12                                                NaN
#
#                                _links.irps.href  \
# 0    /licitacoes/v1/irps?modalidade_licitacao=1
# 1    /licitacoes/v1/irps?modalidade_licitacao=2
# 2    /licitacoes/v1/irps?modalidade_licitacao=3
# 3    /licitacoes/v1/irps?modalidade_licitacao=4
# 4    /licitacoes/v1/irps?modalidade_licitacao=5
# 5    /licitacoes/v1/irps?modalidade_licitacao=6
# 6    /licitacoes/v1/irps?modalidade_licitacao=7
# 7   /licitacoes/v1/irps?modalidade_licitacao=20
# 8   /licitacoes/v1/irps?modalidade_licitacao=22
# 9   /licitacoes/v1/irps?modalidade_licitacao=33
# 10  /licitacoes/v1/irps?modalidade_licitacao=44
# 11                                          NaN
# 12                                          NaN
#
#                                     _links.irps.title  \
# 0   IRPs que resultaram em licitações com esta mod...
# 1   IRPs que resultaram em licitações com esta mod...
# 2   IRPs que resultaram em licitações com esta mod...
# 3   IRPs que resultaram em licitações com esta mod...
# 4   IRPs que resultaram em licitações com esta mod...
# 5   IRPs que resultaram em licitações com esta mod...
# 6   IRPs que resultaram em licitações com esta mod...
# 7   IRPs que resultaram em licitações com esta mod...
# 8   IRPs que resultaram em licitações com esta mod...
# 9   IRPs que resultaram em licitações com esta mod...
# 10  IRPs que resultaram em licitações com esta mod...
# 11                                                NaN
# 12                                                NaN
#
#                      _links.licitacoes.href         _links.licitacoes.title  \
# 0    /licitacoes/v1/licitacoes?modalidade=1  Licitações com esta modalidade
# 1    /licitacoes/v1/licitacoes?modalidade=2  Licitações com esta modalidade
# 2    /licitacoes/v1/licitacoes?modalidade=3  Licitações com esta modalidade
# 3    /licitacoes/v1/licitacoes?modalidade=4  Licitações com esta modalidade
# 4    /licitacoes/v1/licitacoes?modalidade=5  Licitações com esta modalidade
# 5    /licitacoes/v1/licitacoes?modalidade=6  Licitações com esta modalidade
# 6    /licitacoes/v1/licitacoes?modalidade=7  Licitações com esta modalidade
# 7   /licitacoes/v1/licitacoes?modalidade=20  Licitações com esta modalidade
# 8   /licitacoes/v1/licitacoes?modalidade=22  Licitações com esta modalidade
# 9   /licitacoes/v1/licitacoes?modalidade=33  Licitações com esta modalidade
# 10  /licitacoes/v1/licitacoes?modalidade=44  Licitações com esta modalidade
# 11                                      NaN                             NaN
# 12                                      NaN                             NaN
#
#    _links
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12   None

# %%
df_modalidades_carga = df_modalidades[['codigo', 'descricao' ]]
# df_modalidades_carga = df_modalidades_carga.astype(str).apply(lambda x: x.str.encode('utf-8', 'ignore').str.decode('utf-8'))
# df_modalidades_carga['descricao'] = df_modalidades_carga['descricao'].str.normalize('NFKD').str.encode('ascii', 'ignore').str.decode('utf-8')

df_modalidades_carga.head(100)
# Out:
#     codigo                                          descricao
# 0        1  CONVITE                                       ...
# 1        2  TOMADA DE PREÇOS                              ...
# 2        3  CONCORRÊNCIA                                  ...
# 3        4  CONCORRÊNCIA INTERNACIONAL                    ...
# 4        5  PREGÃO                                        ...
# 5        6  DISPENSA DE LICITAÇÃO                         ...
# 6        7  INEXIGIBILIDADE DE LICITAÇÃO                  ...
# 7       20  CONCURSO                                      ...
# 8       22  TOMADA DE PREÇOS POR TÉCNICA E PREÇO          ...
# 9       33  CONCORRÊNCIA POR TÉCNICA E PREÇO              ...
# 10      44  CONCORRÊNCIA INTERNACIONAL POR TÉCNICA E PREÇO...
# 11    9999                         PREGÃO - REGISTRO DE PREÇO
# 12    9997                   CONCORRÊNCIA - REGISTRO DE PREÇO

# %%
# Insere dados de modalidade
resultado = inserir_dados_postgresql(df_modalidades_carga, "modalidade", DB_HOST, DB_PORT, DB_NAME, DB_USER, DB_PASS, excluir_antes=True)

# Exibindo o resultado
print(resultado)
# Out:
# 🗑️ Todos os registros da tabela 'modalidade' foram excluídos.
# 📊 Total de registros a serem inseridos: 13
# ✅ Inseridos 13/13 registros...
# ✅ Registros inseridos com sucesso!

# %% [markdown]
# ---
# ### 3.3) ETL UF
# ---

# %%
import pandas as pd

# Lista de estados do Brasil
estados = [
    ("AC", "Acre"), ("AL", "Alagoas"), ("AP", "Amapá"), ("AM", "Amazonas"),
    ("BA", "Bahia"), ("CE", "Ceará"), ("DF", "Distrito Federal"), ("ES", "Espírito Santo"),
    ("GO", "Goiás"), ("MA", "Maranhão"), ("MT", "Mato Grosso"), ("MS", "Mato Grosso do Sul"),
    ("MG", "Minas Gerais"), ("PA", "Pará"), ("PB", "Paraíba"), ("PR", "Paraná"),
    ("PE", "Pernambuco"), ("PI", "Piauí"), ("RJ", "Rio de Janeiro"), ("RN", "Rio Grande do Norte"),
    ("RS", "Rio Grande do Sul"), ("RO", "Rondônia"), ("RR", "Roraima"), ("SC", "Santa Catarina"),
    ("SP", "São Paulo"), ("SE", "Sergipe"), ("TO", "Tocantins"), ("-3", "Inválido")
]

# Criar o DataFrame
df_estados = pd.DataFrame(estados, columns=["sigla", "descricao"])

# Exibir o DataFrame
df_estados.head()
# Out:
#   sigla descricao
# 0    AC      Acre
# 1    AL   Alagoas
# 2    AP     Amapá
# 3    AM  Amazonas
# 4    BA     Bahia

# %%
# Insere dados de modalidade
resultado = inserir_dados_postgresql(df_estados, "uf", DB_HOST, DB_PORT, DB_NAME, DB_USER, DB_PASS, excluir_antes=True)

# Exibindo o resultado
print(resultado)
# Out:
# 🗑️ Todos os registros da tabela 'uf' foram excluídos.
# 📊 Total de registros a serem inseridos: 28
# ✅ Inseridos 28/28 registros...
# ✅ Registros inseridos com sucesso!

# %% [markdown]
# ---
# ### 3.4) ETL MUNICÍPIO
# ---

# %%
df_licitacoes = processar_diretorio(diretorio, "Licitação")
df_licitacoes.head()
# Out:
# ✅ 4 arquivos processados e 8058 registros carregados.
#    Número Licitação  Código UG                                      Nome UG  \
# 0             12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 1             12023     135008                           EMBRAPA/CPAF-AMAPA
# 2             12023     135020                                 EMBRAPA/CTAA
# 3             12023     135039                                 EMBRAPA/CPAC
# 4             12023     152237                       CAMPUS ARRAIAL DO CABO
#
#    Código Modalidade Compra             Modalidade Compra    Número Processo  \
# 0                         5                        Pregão  21030.002858/2023
# 1                         7  Inexigibilidade de Licitação  21157001423202338
# 2                         7  Inexigibilidade de Licitação  21152.001449/2023
# 3                         7  Inexigibilidade de Licitação  21167.001652/2023
# 4                      9999    Pregão - Registro de Preço  23826000189202327
#
#                                               Objeto  \
# 0  Objeto: Pregão Eletrônico - Contratação de emp...
# 1  Objeto: Aquisição de serviço para atualização ...
# 2  Objeto: Aquisição de Insumos para Utilização n...
# 3  Objeto: Aquisição de Selo GFP para Equipamento...
# 4  Objeto: Pregão Eletrônico - Contratação de emp...
#
#               Situação Licitação  Código Órgão Superior  \
# 0  Evento de Adiamento Publicado                  22000
# 1                      Encerrado                  22000
# 2                      Publicado                  22000
# 3                      Encerrado                  22000
# 4                      Publicado                  26000
#
#                     Nome Órgão Superior  Código Órgão  \
# 0  Ministério da Agricultura e Pecuária         22000
# 1  Ministério da Agricultura e Pecuária         22202
# 2  Ministério da Agricultura e Pecuária         22202
# 3  Ministério da Agricultura e Pecuária         22202
# 4                Ministério da Educação         26433
#
#                                     Nome Órgão  UF        Município  \
# 0  Ministério da Agricultura e Pecuária - Unid  PA            BELEM
# 1  Empresa Brasileira de Pesquisa Agropecuária  AP           MACAPA
# 2  Empresa Brasileira de Pesquisa Agropecuária  RJ   RIO DE JANEIRO
# 3  Empresa Brasileira de Pesquisa Agropecuária  DF         BRASILIA
# 4          Instituto Federal do Rio de Janeiro  RJ  ARRAIAL DO CABO
#
#   Data Resultado Compra Data Abertura Valor Licitação   ano mes
# 0            17/01/2024    26/12/2023     170612,0000  2024  01
# 1            08/01/2024           NaN      26636,4500  2024  01
# 2            02/01/2024           NaN     100061,6000  2024  01
# 3            08/01/2024           NaN       3097,5000  2024  01
# 4            18/01/2024    08/01/2024      11890,0000  2024  01

# %%
df_licitacoes.columns
# Out:
# Index(['Número Licitação', 'Código UG', 'Nome UG', 'Código Modalidade Compra',
#        'Modalidade Compra', 'Número Processo', 'Objeto', 'Situação Licitação',
#        'Código Órgão Superior', 'Nome Órgão Superior', 'Código Órgão',
#        'Nome Órgão', 'UF', 'Município', 'Data Resultado Compra',
#        'Data Abertura', 'Valor Licitação', 'ano', 'mes'],
#       dtype='object')

# %%
df_licitacoes = df_licitacoes.rename(columns={'Número Licitação': 'numero', 
                                              'Código UG': 'codigo_ug',
                                              'Nome UG': 'nome_ug',
                                              'Código Modalidade Compra': 'modalidade_codigo',
                                              'Modalidade Compra': 'modalidade_desc',
                                              'Número Processo': 'num_processo',
                                              'Objeto':'objeto',
                                              'Situação Licitação': 'situacao',
                                              'Código Órgão Superior': 'orgao_codigo_sup',
                                              'Nome Órgão Superior': 'orgao_nome_sup',
                                              'Código Órgão': 'orgao_codigo',
                                              'Nome Órgão': 'orgao_nome', 
                                              'UF': 'uf',
                                              'Município': 'municipio',
                                              'Data Resultado Compra': 'data_compra',
                                              'Data Abertura': 'data_abertura',
                                              'Valor Licitação': 'valor'})


# Criar uma nova coluna concatenada
df_licitacoes["chave_unica"] = (
    df_licitacoes["numero"].astype(str) + "_" +
    df_licitacoes["codigo_ug"].astype(str) + "_" +
    df_licitacoes["modalidade_codigo"].astype(str) + "_" +
    df_licitacoes["ano"].astype(str) + "_" +
    df_licitacoes["mes"].astype(str).str.zfill(2)
)

df_licitacoes.head()
# Out:
#    numero  codigo_ug                                      nome_ug  \
# 0   12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 1   12023     135008                           EMBRAPA/CPAF-AMAPA
# 2   12023     135020                                 EMBRAPA/CTAA
# 3   12023     135039                                 EMBRAPA/CPAC
# 4   12023     152237                       CAMPUS ARRAIAL DO CABO
#
#    modalidade_codigo               modalidade_desc       num_processo  \
# 0                  5                        Pregão  21030.002858/2023
# 1                  7  Inexigibilidade de Licitação  21157001423202338
# 2                  7  Inexigibilidade de Licitação  21152.001449/2023
# 3                  7  Inexigibilidade de Licitação  21167.001652/2023
# 4               9999    Pregão - Registro de Preço  23826000189202327
#
#                                               objeto  \
# 0  Objeto: Pregão Eletrônico - Contratação de emp...
# 1  Objeto: Aquisição de serviço para atualização ...
# 2  Objeto: Aquisição de Insumos para Utilização n...
# 3  Objeto: Aquisição de Selo GFP para Equipamento...
# 4  Objeto: Pregão Eletrônico - Contratação de emp...
#
#                         situacao  orgao_codigo_sup  \
# 0  Evento de Adiamento Publicado             22000
# 1                      Encerrado             22000
# 2                      Publicado             22000
# 3                      Encerrado             22000
# 4                      Publicado             26000
#
#                          orgao_nome_sup  orgao_codigo  \
# 0  Ministério da Agricultura e Pecuária         22000
# 1  Ministério da Agricultura e Pecuária         22202
# 2  Ministério da Agricultura e Pecuária         22202
# 3  Ministério da Agricultura e Pecuária         22202
# 4                Ministério da Educação         26433
#
#                                     orgao_nome  uf        municipio  \
# 0  Ministério da Agricultura e Pecuária - Unid  PA            BELEM
# 1  Empresa Brasileira de Pesquisa Agropecuária  AP           MACAPA
# 2  Empresa Brasileira de Pesquisa Agropecuária  RJ   RIO DE JANEIRO
# 3  Empresa Brasileira de Pesquisa Agropecuária  DF         BRASILIA
# 4          Instituto Federal do Rio de Janeiro  RJ  ARRAIAL DO CABO
#
#   data_compra data_abertura        valor   ano mes                chave_unica
# 0  17/01/2024    26/12/2023  170612,0000  2024  01     12023_130094_5_2024_01
# 1  08/01/2024           NaN   26636,4500  2024  01     12023_135008_7_2024_01
# 2  02/01/2024           NaN  100061,6000  2024  01     12023_135020_7_2024_01
# 3  08/01/2024           NaN    3097,5000  2024  01     12023_135039_7_2024_01
# 4  18/01/2024    08/01/2024   11890,0000  2024  01  12023_152237_9999_2024_01

# %%
df_municipios = df_licitacoes[['uf', 'municipio']].copy()
df_municipios.rename(columns={"uf": "uf_sigla", "municipio": "descricao"}, inplace=True)

df_municipios = df_municipios.drop_duplicates(subset=["uf_sigla", "descricao"])

df_municipios.head()
# Out:
#   uf_sigla        descricao
# 0       PA            BELEM
# 1       AP           MACAPA
# 2       RJ   RIO DE JANEIRO
# 3       DF         BRASILIA
# 4       RJ  ARRAIAL DO CABO

# %%
# Insere dados
resultado = inserir_dados_postgresql(df_municipios, "municipio", DB_HOST, DB_PORT, DB_NAME, DB_USER, DB_PASS, excluir_antes=True)

# Exibindo o resultado
print(resultado)
# Out:
# 🗑️ Todos os registros da tabela 'municipio' foram excluídos.
# 📊 Total de registros a serem inseridos: 274
# ✅ Inseridos 274/274 registros...
# ✅ Registros inseridos com sucesso!

# %%
# Chamar a função para carregar a tabela do PostgreSQL
df_municipios_postgree = ler_tabela_postgresql("municipio", DB_HOST, DB_PORT, DB_NAME, DB_USER, DB_PASS)

# Exibir as 5 primeiras linhas
df_municipios_postgree.head()
# Out:
# ✅ Tabela 'municipio' carregada com sucesso! 274 registros encontrados.
#    id uf_sigla        descricao
# 0   1       PA            BELEM
# 1   2       AP           MACAPA
# 2   3       RJ   RIO DE JANEIRO
# 3   4       DF         BRASILIA
# 4   5       RJ  ARRAIAL DO CABO

# %% [markdown]
# ---
# ### 3.5) ETL LICITACAO
# ---

# %%
df_licitacoes.shape
# Out:
# (8058, 20)

# %%
# Fazer o merge
df_licitacoes = df_licitacoes.merge(
    df_municipios_postgree[["id", "uf_sigla", "descricao"]],  # Apenas colunas necessárias
    left_on=["uf", "municipio"],  # Colunas para correspondência
    right_on=["uf_sigla", "descricao"],
    how="left"  # Mantém todas as linhas de df_licitacoes_carga
)

# Renomear a coluna 'id' para 'municipio_id'
df_licitacoes.rename(columns={"id": "municipio_id"}, inplace=True)

# Exibir os primeiros registros
df_licitacoes.head(5)
# Out:
#    numero  codigo_ug                                      nome_ug  \
# 0   12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 1   12023     135008                           EMBRAPA/CPAF-AMAPA
# 2   12023     135020                                 EMBRAPA/CTAA
# 3   12023     135039                                 EMBRAPA/CPAC
# 4   12023     152237                       CAMPUS ARRAIAL DO CABO
#
#    modalidade_codigo               modalidade_desc       num_processo  \
# 0                  5                        Pregão  21030.002858/2023
# 1                  7  Inexigibilidade de Licitação  21157001423202338
# 2                  7  Inexigibilidade de Licitação  21152.001449/2023
# 3                  7  Inexigibilidade de Licitação  21167.001652/2023
# 4               9999    Pregão - Registro de Preço  23826000189202327
#
#                                               objeto  \
# 0  Objeto: Pregão Eletrônico - Contratação de emp...
# 1  Objeto: Aquisição de serviço para atualização ...
# 2  Objeto: Aquisição de Insumos para Utilização n...
# 3  Objeto: Aquisição de Selo GFP para Equipamento...
# 4  Objeto: Pregão Eletrônico - Contratação de emp...
#
#                         situacao  orgao_codigo_sup  \
# 0  Evento de Adiamento Publicado             22000
# 1                      Encerrado             22000
# 2                      Publicado             22000
# 3                      Encerrado             22000
# 4                      Publicado             26000
#
#                          orgao_nome_sup  ...        municipio data_compra  \
# 0  Ministério da Agricultura e Pecuária  ...            BELEM  17/01/2024
# 1  Ministério da Agricultura e Pecuária  ...           MACAPA  08/01/2024
# 2  Ministério da Agricultura e Pecuária  ...   RIO DE JANEIRO  02/01/2024
# 3  Ministério da Agricultura e Pecuária  ...         BRASILIA  08/01/2024
# 4                Ministério da Educação  ...  ARRAIAL DO CABO  18/01/2024
#
#   data_abertura        valor   ano mes                chave_unica  \
# 0    26/12/2023  170612,0000  2024  01     12023_130094_5_2024_01
# 1           NaN   26636,4500  2024  01     12023_135008_7_2024_01
# 2           NaN  100061,6000  2024  01     12023_135020_7_2024_01
# 3           NaN    3097,5000  2024  01     12023_135039_7_2024_01
# 4    08/01/2024   11890,0000  2024  01  12023_152237_9999_2024_01
#
#   municipio_id uf_sigla        descricao
# 0            1       PA            BELEM
# 1            2       AP           MACAPA
# 2            3       RJ   RIO DE JANEIRO
# 3            4       DF         BRASILIA
# 4            5       RJ  ARRAIAL DO CABO
#
# [5 rows x 23 columns]

# %%
df_licitacoes.shape
# Out:
# (8058, 23)

# %%
# Criar uma cópia do DataFrame apenas com as colunas relevantes
df_licitacoes_carga = df_licitacoes[
    [
        "numero",
        "codigo_ug",
        "modalidade_codigo",
        "num_processo",
        "objeto",
        "situacao",
        "orgao_codigo",
        "municipio_id",
        "data_compra",
        "data_abertura",
        "valor",
        "ano",
        "mes",
        "chave_unica"
    ]
].copy()

# Substituir valores inválidos ('None', 'nan', np.nan, '') por None (NULL)
df_licitacoes_carga.replace({"None": None, "nan": None, np.nan: None, "": None}, inplace=True)

# Converter colunas de data para o formato correto ('YYYY-MM-DD') SEM '00:00:00'
df_licitacoes_carga["data_compra"] = pd.to_datetime(
    df_licitacoes_carga["data_compra"], format="%d/%m/%Y", errors="coerce"
).dt.date

df_licitacoes_carga["data_abertura"] = pd.to_datetime(
    df_licitacoes_carga["data_abertura"], format="%d/%m/%Y", errors="coerce"
).dt.date

# Garantir que os valores numéricos estejam no formato correto
df_licitacoes_carga["valor"] = (
    df_licitacoes_carga["valor"]
    .astype(str)
    .str.replace(",", ".", regex=True)
    .astype(float)
)

# Converter NaT para None antes da inserção no PostgreSQL
# Converter colunas de data corretamente para evitar erro no PostgreSQL
df_licitacoes_carga["data_compra"] = df_licitacoes_carga["data_compra"].apply(lambda x: x if pd.notna(x) else None)
df_licitacoes_carga["data_abertura"] = df_licitacoes_carga["data_abertura"].apply(lambda x: x if pd.notna(x) else None)

# Garantir que colunas de data sejam tratadas corretamente e passem None (NULL) no PostgreSQL
df_licitacoes_carga["data_compra"] = df_licitacoes_carga["data_compra"].apply(lambda x: None if pd.isna(x) else x)
df_licitacoes_carga["data_abertura"] = df_licitacoes_carga["data_abertura"].apply(lambda x: None if pd.isna(x) else x)


# Conferir se os valores nulos foram corretamente ajustados
print(df_licitacoes_carga[["data_compra", "data_abertura", "valor"]].head(10))
# Out:
#   data_compra data_abertura       valor
# 0  2024-01-17    2023-12-26   170612.00
# 1  2024-01-08          None    26636.45
# 2  2024-01-02          None   100061.60
# 3  2024-01-08          None     3097.50
# 4  2024-01-18    2024-01-08    11890.00
# 5  2024-01-15    2023-10-30        0.00
# 6  2024-01-16          None  4390280.88
# 7  2024-01-02    2023-12-12   100444.08
# 8  2024-01-19    2023-12-19     5185.74
# 9  2024-01-26    2023-04-20  2062431.00

# %%
# Insere dados de licitacao
resultado = inserir_dados_postgresql(df_licitacoes_carga, "licitacao", DB_HOST, DB_PORT, DB_NAME, DB_USER, DB_PASS, excluir_antes=True)

# Exibindo o resultado
print(resultado)
# Out:
# 🗑️ Todos os registros da tabela 'licitacao' foram excluídos.
# 📊 Total de registros a serem inseridos: 8058
# ✅ Inseridos 8058/8058 registros...
# ✅ Registros inseridos com sucesso!

# %%
# Chamar a função para carregar a tabela do PostgreSQL
df_licitacoes_postgree = ler_tabela_postgresql("licitacao", DB_HOST, DB_PORT, DB_NAME, DB_USER, DB_PASS)

# Exibir as 5 primeiras linhas
df_licitacoes_postgree.head()
# Out:
# ✅ Tabela 'licitacao' carregada com sucesso! 8058 registros encontrados.
#    id  numero orgao_codigo  codigo_ug  modalidade_codigo   ano  mes  \
# 0   1   12023        22000     130094                  5  2024    1
# 1   2   12023        22202     135008                  7  2024    1
# 2   3   12023        22202     135020                  7  2024    1
# 3   4   12023        22202     135039                  7  2024    1
# 4   5   12023        26433     152237               9999  2024    1
#
#                  chave_unica       num_processo  \
# 0     12023_130094_5_2024_01  21030.002858/2023
# 1     12023_135008_7_2024_01  21157001423202338
# 2     12023_135020_7_2024_01  21152.001449/2023
# 3     12023_135039_7_2024_01  21167.001652/2023
# 4  12023_152237_9999_2024_01  23826000189202327
#
#                                               objeto  \
# 0  Objeto: Pregão Eletrônico - Contratação de emp...
# 1  Objeto: Aquisição de serviço para atualização ...
# 2  Objeto: Aquisição de Insumos para Utilização n...
# 3  Objeto: Aquisição de Selo GFP para Equipamento...
# 4  Objeto: Pregão Eletrônico - Contratação de emp...
#
#                         situacao  municipio_id data_compra data_abertura  \
# 0  Evento de Adiamento Publicado             1  2024-01-17    2023-12-26
# 1                      Encerrado             2  2024-01-08          None
# 2                      Publicado             3  2024-01-02          None
# 3                      Encerrado             4  2024-01-08          None
# 4                      Publicado             5  2024-01-18    2024-01-08
#
#        valor
# 0  170612.00
# 1   26636.45
# 2  100061.60
# 3    3097.50
# 4   11890.00

# %% [markdown]
# ---
# ### 3.6) ETL CNPJ
# ---

# %%
df_participantes = processar_diretorio(diretorio, "ParticipantesLicitação")
df_participantes.head()
# Out:
# ✅ 4 arquivos processados e 508814 registros carregados.
#    Número Licitação  Código UG                                      Nome UG  \
# 0             12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 1             12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 2             12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 3             12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 4             12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
#
#    Código Modalidade Compra Modalidade Compra    Número Processo  \
# 0                         5            Pregão  21030.002858/2023
# 1                         5            Pregão  21030.002858/2023
# 2                         5            Pregão  21030.002858/2023
# 3                         5            Pregão  21030.002858/2023
# 4                         5            Pregão  21030.002858/2023
#
#    Código Órgão                                   Nome Órgão  \
# 0         22000  Ministério da Agricultura e Pecuária - Unid
# 1         22000  Ministério da Agricultura e Pecuária - Unid
# 2         22000  Ministério da Agricultura e Pecuária - Unid
# 3         22000  Ministério da Agricultura e Pecuária - Unid
# 4         22000  Ministério da Agricultura e Pecuária - Unid
#
#        Código Item Compra Descrição Item Compra Código Participante  \
# 0  1300940500001202300001    SERVICO ENGENHARIA      35230250000100
# 1  1300940500001202300001    SERVICO ENGENHARIA      08311793000171
# 2  1300940500001202300001    SERVICO ENGENHARIA      23274187000117
# 3  1300940500001202300001    SERVICO ENGENHARIA      14986916000177
# 4  1300940500001202300001    SERVICO ENGENHARIA      05210095000191
#
#                                    Nome Participante Flag Vencedor   ano mes
# 0       CLEDENIR ALVES DA SILVA - SERVICOS ELETRICOS           NÃO  2024  01
# 1                            PLENNUS ENGENHARIA LTDA           NÃO  2024  01
# 2                              TEMPORY SERVICOS LTDA           NÃO  2024  01
# 3                   CORDEL AUTOMACAO & SERVICOS LTDA           NÃO  2024  01
# 4  PRESCOM - COMERCIO E SERVICOS DE CONSTRUCAO CI...           NÃO  2024  01

# %%
df_participantes.columns
# Out:
# Index(['Número Licitação', 'Código UG', 'Nome UG', 'Código Modalidade Compra',
#        'Modalidade Compra', 'Número Processo', 'Código Órgão', 'Nome Órgão',
#        'Código Item Compra', 'Descrição Item Compra', 'Código Participante',
#        'Nome Participante', 'Flag Vencedor', 'ano', 'mes'],
#       dtype='object')

# %%
df_participantes = df_participantes.rename(columns={'Número Licitação': 'numero', 
                                              'Código UG': 'codigo_ug',
                                              'Nome UG': 'nome_ug',
                                              'Código Modalidade Compra': 'modalidade_codigo',
                                              'Modalidade Compra': 'modalidade_desc',
                                              'Número Processo': 'num_processo',
                                              'Código Órgão': 'orgao_codigo',
                                              'Nome Órgão': 'orgao_nome', 
                                              'Código Item Compra': 'item_codigo',
                                              'Descrição Item Compra': 'item_descricao',
                                              'Código Participante': 'cnpj_codigo',
                                              'Nome Participante': 'cnpj_nome',
                                              'Flag Vencedor': 'vencedor_flag'})

df_participantes.head()
# Out:
#    numero  codigo_ug                                      nome_ug  \
# 0   12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 1   12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 2   12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 3   12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 4   12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
#
#    modalidade_codigo modalidade_desc       num_processo  orgao_codigo  \
# 0                  5          Pregão  21030.002858/2023         22000
# 1                  5          Pregão  21030.002858/2023         22000
# 2                  5          Pregão  21030.002858/2023         22000
# 3                  5          Pregão  21030.002858/2023         22000
# 4                  5          Pregão  21030.002858/2023         22000
#
#                                     orgao_nome             item_codigo  \
# 0  Ministério da Agricultura e Pecuária - Unid  1300940500001202300001
# 1  Ministério da Agricultura e Pecuária - Unid  1300940500001202300001
# 2  Ministério da Agricultura e Pecuária - Unid  1300940500001202300001
# 3  Ministério da Agricultura e Pecuária - Unid  1300940500001202300001
# 4  Ministério da Agricultura e Pecuária - Unid  1300940500001202300001
#
#        item_descricao     cnpj_codigo  \
# 0  SERVICO ENGENHARIA  35230250000100
# 1  SERVICO ENGENHARIA  08311793000171
# 2  SERVICO ENGENHARIA  23274187000117
# 3  SERVICO ENGENHARIA  14986916000177
# 4  SERVICO ENGENHARIA  05210095000191
#
#                                            cnpj_nome vencedor_flag   ano mes
# 0       CLEDENIR ALVES DA SILVA - SERVICOS ELETRICOS           NÃO  2024  01
# 1                            PLENNUS ENGENHARIA LTDA           NÃO  2024  01
# 2                              TEMPORY SERVICOS LTDA           NÃO  2024  01
# 3                   CORDEL AUTOMACAO & SERVICOS LTDA           NÃO  2024  01
# 4  PRESCOM - COMERCIO E SERVICOS DE CONSTRUCAO CI...           NÃO  2024  01

# %%
df_itens_licitacao = processar_diretorio(diretorio, "ItemLicitação")
df_itens_licitacao.head()
# Out:
# ✅ 4 arquivos processados e 175679 registros carregados.
#    Número Licitação  Código UG                                      Nome UG  \
# 0             12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 1             12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 2             12023     135008                           EMBRAPA/CPAF-AMAPA
# 3             12023     135020                                 EMBRAPA/CTAA
# 4             12023     135020                                 EMBRAPA/CTAA
#
#    Código Modalidade Compra             Modalidade Compra    Número Processo  \
# 0                         5                        Pregão  21030.002858/2023
# 1                         5                        Pregão  21030.002858/2023
# 2                         7  Inexigibilidade de Licitação  21157001423202338
# 3                         7  Inexigibilidade de Licitação  21152.001449/2023
# 4                         7  Inexigibilidade de Licitação  21152.001449/2023
#
#    Código Órgão                                   Nome Órgão  \
# 0         22000  Ministério da Agricultura e Pecuária - Unid
# 1         22000  Ministério da Agricultura e Pecuária - Unid
# 2         22202  Empresa Brasileira de Pesquisa Agropecuária
# 3         22202  Empresa Brasileira de Pesquisa Agropecuária
# 4         22202  Empresa Brasileira de Pesquisa Agropecuária
#
#        Código Item Compra                                          Descrição  \
# 0  1300940500001202300001                                 SERVICO ENGENHARIA
# 1  1300940500001202300002                                 SERVICO ENGENHARIA
# 2  1350080700001202300001  MANUTENCAO DE SOFTWARE (CORRETIVA, PREVENTIVA,...
# 3  1350200700001202300001                                 FILTRO LABORATÓRIO
# 4  1350200700001202300002                                 FILTRO LABORATÓRIO
#
#    Quantidade Item  Valor Item Código Vencedor  \
# 0                1  99500,0000  24426491000103
# 1                1  71112,0000  24426491000103
# 2                1  26636,4500  05837045000139
# 3                7  26674,2000  07700042000184
# 4               14  50587,6000  07700042000184
#
#                                Nome Vencedor   ano mes
# 0         AVANTI CONSTRUCOES E SERVICOS LTDA  2024  01
# 1         AVANTI CONSTRUCOES E SERVICOS LTDA  2024  01
# 2  MEGASOFTWARE SOLUCOES EM INFORMATICA LTDA  2024  01
# 3               TECNOGLOBO EQUIPAMENTOS LTDA  2024  01
# 4               TECNOGLOBO EQUIPAMENTOS LTDA  2024  01

# %%
df_itens_licitacao.columns
# Out:
# Index(['Número Licitação', 'Código UG', 'Nome UG', 'Código Modalidade Compra',
#        'Modalidade Compra', 'Número Processo', 'Código Órgão', 'Nome Órgão',
#        'Código Item Compra', 'Descrição', 'Quantidade Item', 'Valor Item',
#        'Código Vencedor', 'Nome Vencedor', 'ano', 'mes'],
#       dtype='object')

# %%
df_itens_licitacao = df_itens_licitacao.rename(columns={'Número Licitação': 'numero', 
                                              'Código UG': 'codigo_ug',
                                              'Nome UG': 'nome_ug',
                                              'Código Modalidade Compra': 'modalidade_codigo',
                                              'Modalidade Compra': 'modalidade_desc',
                                              'Número Processo': 'num_processo',
                                              'Código Órgão': 'orgao_codigo',
                                              'Nome Órgão': 'orgao_nome', 
                                              'Código Item Compra': 'item_compra_codigo',
                                              'Descrição': 'item_compra_descricao',
                                              'Quantidade Item': 'item_compra_qtde',
                                              'Valor Item': 'item_compra_valor',
                                              'Código Vencedor': 'vencedor_codigo', 
                                              'Nome Vencedor': 'vencedor_nome'})


df_itens_licitacao.head()
# Out:
#    numero  codigo_ug                                      nome_ug  \
# 0   12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 1   12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 2   12023     135008                           EMBRAPA/CPAF-AMAPA
# 3   12023     135020                                 EMBRAPA/CTAA
# 4   12023     135020                                 EMBRAPA/CTAA
#
#    modalidade_codigo               modalidade_desc       num_processo  \
# 0                  5                        Pregão  21030.002858/2023
# 1                  5                        Pregão  21030.002858/2023
# 2                  7  Inexigibilidade de Licitação  21157001423202338
# 3                  7  Inexigibilidade de Licitação  21152.001449/2023
# 4                  7  Inexigibilidade de Licitação  21152.001449/2023
#
#    orgao_codigo                                   orgao_nome  \
# 0         22000  Ministério da Agricultura e Pecuária - Unid
# 1         22000  Ministério da Agricultura e Pecuária - Unid
# 2         22202  Empresa Brasileira de Pesquisa Agropecuária
# 3         22202  Empresa Brasileira de Pesquisa Agropecuária
# 4         22202  Empresa Brasileira de Pesquisa Agropecuária
#
#        item_compra_codigo                              item_compra_descricao  \
# 0  1300940500001202300001                                 SERVICO ENGENHARIA
# 1  1300940500001202300002                                 SERVICO ENGENHARIA
# 2  1350080700001202300001  MANUTENCAO DE SOFTWARE (CORRETIVA, PREVENTIVA,...
# 3  1350200700001202300001                                 FILTRO LABORATÓRIO
# 4  1350200700001202300002                                 FILTRO LABORATÓRIO
#
#    item_compra_qtde item_compra_valor vencedor_codigo  \
# 0                 1        99500,0000  24426491000103
# 1                 1        71112,0000  24426491000103
# 2                 1        26636,4500  05837045000139
# 3                 7        26674,2000  07700042000184
# 4                14        50587,6000  07700042000184
#
#                                vencedor_nome   ano mes
# 0         AVANTI CONSTRUCOES E SERVICOS LTDA  2024  01
# 1         AVANTI CONSTRUCOES E SERVICOS LTDA  2024  01
# 2  MEGASOFTWARE SOLUCOES EM INFORMATICA LTDA  2024  01
# 3               TECNOGLOBO EQUIPAMENTOS LTDA  2024  01
# 4               TECNOGLOBO EQUIPAMENTOS LTDA  2024  01

# %%
# Criar um novo DataFrame apenas com as colunas relevantes de cada DataFrame
df_participantes_selected = df_participantes[["cnpj_codigo", "cnpj_nome"]].copy()
df_itens_licitacao_selected = df_itens_licitacao[["vencedor_codigo", "vencedor_nome"]].copy()

# Concatenar os DataFrames, mantendo as colunas distintas
df_consolidado = pd.concat([
    df_participantes_selected.rename(columns={"cnpj_codigo": "codigo", "cnpj_nome": "nome"}),
    df_itens_licitacao_selected.rename(columns={"vencedor_codigo": "codigo", "vencedor_nome": "nome"})
], ignore_index=True)

# Remover duplicatas baseando-se nas colunas 'codigo' e 'nome'
df_cpf = df_consolidado.drop_duplicates(subset=["codigo", "nome"])

# Exibir o DataFrame final
df_cpf.head()
# Out:
#            codigo                                               nome
# 0  35230250000100       CLEDENIR ALVES DA SILVA - SERVICOS ELETRICOS
# 1  08311793000171                            PLENNUS ENGENHARIA LTDA
# 2  23274187000117                              TEMPORY SERVICOS LTDA
# 3  14986916000177                   CORDEL AUTOMACAO & SERVICOS LTDA
# 4  05210095000191  PRESCOM - COMERCIO E SERVICOS DE CONSTRUCAO CI...

# %%
df_cpf.shape
# Out:
# (16527, 2)

# %%
df_duplicados = df_cpf[df_cpf.duplicated(subset=['codigo'], keep=False)]
df_duplicados
# Out:
# Empty DataFrame
# Columns: [codigo, nome]
# Index: []

# %%
# Insere dados de cnpj
resultado = inserir_dados_postgresql(df_cpf, "cnpj", DB_HOST, DB_PORT, DB_NAME, DB_USER, DB_PASS, excluir_antes=True)

# Exibindo o resultado
print(resultado)
# Out:
# 🗑️ Todos os registros da tabela 'cnpj' foram excluídos.
# 📊 Total de registros a serem inseridos: 16527
# ✅ Inseridos 10000/16527 registros...
# ✅ Inseridos 16527/16527 registros...
# ✅ Registros inseridos com sucesso!

# %% [markdown]
# ---
# ### 3.7) ETL ITEM
# ---

# %%
df_itens_licitacao = processar_diretorio(diretorio, "ItemLicitação")
df_itens_licitacao.head()
# Out:
# ✅ 4 arquivos processados e 175679 registros carregados.
#    Número Licitação  Código UG                                      Nome UG  \
# 0             12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 1             12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 2             12023     135008                           EMBRAPA/CPAF-AMAPA
# 3             12023     135020                                 EMBRAPA/CTAA
# 4             12023     135020                                 EMBRAPA/CTAA
#
#    Código Modalidade Compra             Modalidade Compra    Número Processo  \
# 0                         5                        Pregão  21030.002858/2023
# 1                         5                        Pregão  21030.002858/2023
# 2                         7  Inexigibilidade de Licitação  21157001423202338
# 3                         7  Inexigibilidade de Licitação  21152.001449/2023
# 4                         7  Inexigibilidade de Licitação  21152.001449/2023
#
#    Código Órgão                                   Nome Órgão  \
# 0         22000  Ministério da Agricultura e Pecuária - Unid
# 1         22000  Ministério da Agricultura e Pecuária - Unid
# 2         22202  Empresa Brasileira de Pesquisa Agropecuária
# 3         22202  Empresa Brasileira de Pesquisa Agropecuária
# 4         22202  Empresa Brasileira de Pesquisa Agropecuária
#
#        Código Item Compra                                          Descrição  \
# 0  1300940500001202300001                                 SERVICO ENGENHARIA
# 1  1300940500001202300002                                 SERVICO ENGENHARIA
# 2  1350080700001202300001  MANUTENCAO DE SOFTWARE (CORRETIVA, PREVENTIVA,...
# 3  1350200700001202300001                                 FILTRO LABORATÓRIO
# 4  1350200700001202300002                                 FILTRO LABORATÓRIO
#
#    Quantidade Item  Valor Item Código Vencedor  \
# 0                1  99500,0000  24426491000103
# 1                1  71112,0000  24426491000103
# 2                1  26636,4500  05837045000139
# 3                7  26674,2000  07700042000184
# 4               14  50587,6000  07700042000184
#
#                                Nome Vencedor   ano mes
# 0         AVANTI CONSTRUCOES E SERVICOS LTDA  2024  01
# 1         AVANTI CONSTRUCOES E SERVICOS LTDA  2024  01
# 2  MEGASOFTWARE SOLUCOES EM INFORMATICA LTDA  2024  01
# 3               TECNOGLOBO EQUIPAMENTOS LTDA  2024  01
# 4               TECNOGLOBO EQUIPAMENTOS LTDA  2024  01

# %%
df_itens_licitacao.shape
# Out:
# (175679, 16)

# %%
df_itens_licitacao = df_itens_licitacao.rename(columns={'Número Licitação': 'numero', 
                                              'Código UG': 'codigo_ug',
                                              'Nome UG': 'nome_ug',
                                              'Código Modalidade Compra': 'modalidade_codigo',
                                              'Modalidade Compra': 'modalidade_desc',
                                              'Número Processo': 'num_processo',
                                              'Objeto':'objeto',
                                              'Situação Licitação': 'situacao',
                                              'Código Órgão Superior': 'orgao_codigo_sup',
                                              'Nome Órgão Superior': 'orgao_nome_sup',
                                              'Código Órgão': 'orgao_codigo',
                                              'Nome Órgão': 'orgao_nome', 
                                              'Código Item Compra': 'item_codigo',
                                              'Descrição': 'item_descricao',
                                              'Quantidade Item': 'item_qtde',
                                              'Valor Item': 'item_valor',
                                              'Código Vencedor': 'vencedor_cnpj',
                                              'Nome Vencedor': 'vencedor_nome',
                                              'UF': 'uf',
                                              'Município': 'municipio',
                                              'Data Resultado Compra': 'data_compra',
                                              'Data Abertura': 'data_abertura',
                                              'Valor Licitação': 'valor'})

df_itens_licitacao.head()
# Out:
#    numero  codigo_ug                                      nome_ug  \
# 0   12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 1   12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 2   12023     135008                           EMBRAPA/CPAF-AMAPA
# 3   12023     135020                                 EMBRAPA/CTAA
# 4   12023     135020                                 EMBRAPA/CTAA
#
#    modalidade_codigo               modalidade_desc       num_processo  \
# 0                  5                        Pregão  21030.002858/2023
# 1                  5                        Pregão  21030.002858/2023
# 2                  7  Inexigibilidade de Licitação  21157001423202338
# 3                  7  Inexigibilidade de Licitação  21152.001449/2023
# 4                  7  Inexigibilidade de Licitação  21152.001449/2023
#
#    orgao_codigo                                   orgao_nome  \
# 0         22000  Ministério da Agricultura e Pecuária - Unid
# 1         22000  Ministério da Agricultura e Pecuária - Unid
# 2         22202  Empresa Brasileira de Pesquisa Agropecuária
# 3         22202  Empresa Brasileira de Pesquisa Agropecuária
# 4         22202  Empresa Brasileira de Pesquisa Agropecuária
#
#               item_codigo                                     item_descricao  \
# 0  1300940500001202300001                                 SERVICO ENGENHARIA
# 1  1300940500001202300002                                 SERVICO ENGENHARIA
# 2  1350080700001202300001  MANUTENCAO DE SOFTWARE (CORRETIVA, PREVENTIVA,...
# 3  1350200700001202300001                                 FILTRO LABORATÓRIO
# 4  1350200700001202300002                                 FILTRO LABORATÓRIO
#
#    item_qtde  item_valor   vencedor_cnpj  \
# 0          1  99500,0000  24426491000103
# 1          1  71112,0000  24426491000103
# 2          1  26636,4500  05837045000139
# 3          7  26674,2000  07700042000184
# 4         14  50587,6000  07700042000184
#
#                                vencedor_nome   ano mes
# 0         AVANTI CONSTRUCOES E SERVICOS LTDA  2024  01
# 1         AVANTI CONSTRUCOES E SERVICOS LTDA  2024  01
# 2  MEGASOFTWARE SOLUCOES EM INFORMATICA LTDA  2024  01
# 3               TECNOGLOBO EQUIPAMENTOS LTDA  2024  01
# 4               TECNOGLOBO EQUIPAMENTOS LTDA  2024  01

# %%
df_itens_licitacao['item_codigo'] = df_itens_licitacao.apply(lambda row: (
                        f"{str(row['codigo_ug']).zfill(6)}"
                        f"{str(row['modalidade_codigo']).zfill(2)}"
                        f"{str(row['numero']).zfill(5)}"
                        f"{str(row['ano']).zfill(4)}"
                        f"99999"
                    ) if pd.isnull(row['item_codigo']) else row['item_codigo'], axis=1)

# %%
df_itens_licitacao.shape
# Out:
# (175679, 16)

# %%
# Criar uma nova coluna concatenada
df_itens_licitacao["chave_unica"] = (
    df_itens_licitacao["numero"].astype(str) + "_" +
    df_itens_licitacao["codigo_ug"].astype(str) + "_" +
    df_itens_licitacao["modalidade_codigo"].astype(str) + "_" +
    df_itens_licitacao["ano"].astype(str) + "_" +
    df_itens_licitacao["mes"].astype(str)
)

# Exibir o DataFrame atualizado
df_itens_licitacao.head()
# Out:
#    numero  codigo_ug                                      nome_ug  \
# 0   12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 1   12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 2   12023     135008                           EMBRAPA/CPAF-AMAPA
# 3   12023     135020                                 EMBRAPA/CTAA
# 4   12023     135020                                 EMBRAPA/CTAA
#
#    modalidade_codigo               modalidade_desc       num_processo  \
# 0                  5                        Pregão  21030.002858/2023
# 1                  5                        Pregão  21030.002858/2023
# 2                  7  Inexigibilidade de Licitação  21157001423202338
# 3                  7  Inexigibilidade de Licitação  21152.001449/2023
# 4                  7  Inexigibilidade de Licitação  21152.001449/2023
#
#    orgao_codigo                                   orgao_nome  \
# 0         22000  Ministério da Agricultura e Pecuária - Unid
# 1         22000  Ministério da Agricultura e Pecuária - Unid
# 2         22202  Empresa Brasileira de Pesquisa Agropecuária
# 3         22202  Empresa Brasileira de Pesquisa Agropecuária
# 4         22202  Empresa Brasileira de Pesquisa Agropecuária
#
#               item_codigo                                     item_descricao  \
# 0  1300940500001202300001                                 SERVICO ENGENHARIA
# 1  1300940500001202300002                                 SERVICO ENGENHARIA
# 2  1350080700001202300001  MANUTENCAO DE SOFTWARE (CORRETIVA, PREVENTIVA,...
# 3  1350200700001202300001                                 FILTRO LABORATÓRIO
# 4  1350200700001202300002                                 FILTRO LABORATÓRIO
#
#    item_qtde  item_valor   vencedor_cnpj  \
# 0          1  99500,0000  24426491000103
# 1          1  71112,0000  24426491000103
# 2          1  26636,4500  05837045000139
# 3          7  26674,2000  07700042000184
# 4         14  50587,6000  07700042000184
#
#                                vencedor_nome   ano mes             chave_unica
# 0         AVANTI CONSTRUCOES E SERVICOS LTDA  2024  01  12023_130094_5_2024_01
# 1         AVANTI CONSTRUCOES E SERVICOS LTDA  2024  01  12023_130094_5_2024_01
# 2  MEGASOFTWARE SOLUCOES EM INFORMATICA LTDA  2024  01  12023_135008_7_2024_01
# 3               TECNOGLOBO EQUIPAMENTOS LTDA  2024  01  12023_135020_7_2024_01
# 4               TECNOGLOBO EQUIPAMENTOS LTDA  2024  01  12023_135020_7_2024_01

# %%
#  Fazer o merge para trazer 'id' como 'licitacao_id' para df_participantes
df_itens_licitacao = df_itens_licitacao.merge(
    df_licitacoes_postgree[["id", "chave_unica"]],  # Apenas colunas necessárias
    on="chave_unica",  # Coluna para correspondência
    how="left"  # Mantém todas as linhas de df_participantes
)

# Renomear a coluna 'id' para 'licitacao_id'
df_itens_licitacao.rename(columns={"id": "licitacao_id"}, inplace=True)

# Exibir o DataFrame atualizado
df_itens_licitacao.head()
# Out:
#    numero  codigo_ug                                      nome_ug  \
# 0   12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 1   12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 2   12023     135008                           EMBRAPA/CPAF-AMAPA
# 3   12023     135020                                 EMBRAPA/CTAA
# 4   12023     135020                                 EMBRAPA/CTAA
#
#    modalidade_codigo               modalidade_desc       num_processo  \
# 0                  5                        Pregão  21030.002858/2023
# 1                  5                        Pregão  21030.002858/2023
# 2                  7  Inexigibilidade de Licitação  21157001423202338
# 3                  7  Inexigibilidade de Licitação  21152.001449/2023
# 4                  7  Inexigibilidade de Licitação  21152.001449/2023
#
#    orgao_codigo                                   orgao_nome  \
# 0         22000  Ministério da Agricultura e Pecuária - Unid
# 1         22000  Ministério da Agricultura e Pecuária - Unid
# 2         22202  Empresa Brasileira de Pesquisa Agropecuária
# 3         22202  Empresa Brasileira de Pesquisa Agropecuária
# 4         22202  Empresa Brasileira de Pesquisa Agropecuária
#
#               item_codigo                                     item_descricao  \
# 0  1300940500001202300001                                 SERVICO ENGENHARIA
# 1  1300940500001202300002                                 SERVICO ENGENHARIA
# 2  1350080700001202300001  MANUTENCAO DE SOFTWARE (CORRETIVA, PREVENTIVA,...
# 3  1350200700001202300001                                 FILTRO LABORATÓRIO
# 4  1350200700001202300002                                 FILTRO LABORATÓRIO
#
#    item_qtde  item_valor   vencedor_cnpj  \
# 0          1  99500,0000  24426491000103
# 1          1  71112,0000  24426491000103
# 2          1  26636,4500  05837045000139
# 3          7  26674,2000  07700042000184
# 4         14  50587,6000  07700042000184
#
#                                vencedor_nome   ano mes  \
# 0         AVANTI CONSTRUCOES E SERVICOS LTDA  2024  01
# 1         AVANTI CONSTRUCOES E SERVICOS LTDA  2024  01
# 2  MEGASOFTWARE SOLUCOES EM INFORMATICA LTDA  2024  01
# 3               TECNOGLOBO EQUIPAMENTOS LTDA  2024  01
# 4               TECNOGLOBO EQUIPAMENTOS LTDA  2024  01
#
#               chave_unica  licitacao_id
# 0  12023_130094_5_2024_01             1
# 1  12023_130094_5_2024_01             1
# 2  12023_135008_7_2024_01             2
# 3  12023_135020_7_2024_01             3
# 4  12023_135020_7_2024_01             3

# %%
df_itens_licitacao.shape
# Out:
# (175679, 18)

# %%
df_itens_licitacao['item_valor'] = df_itens_licitacao['item_valor'].astype(str).str.replace(',', '.').astype(float)

# %%
df_itens_licitacao_carga = df_itens_licitacao[['licitacao_id',
                                               'item_codigo',
                                               'item_descricao',
                                               'item_qtde',
                                               'item_valor',
                                               'vencedor_cnpj']].copy()

# %%
# Insere dados de cnpj
resultado = inserir_dados_postgresql(df_itens_licitacao_carga, "item", DB_HOST, DB_PORT, DB_NAME, DB_USER, DB_PASS, excluir_antes=True)

# Exibindo o resultado
print(resultado)
# Out:
# 🗑️ Todos os registros da tabela 'item' foram excluídos.
# 📊 Total de registros a serem inseridos: 175679
# ✅ Inseridos 10000/175679 registros...
# ✅ Inseridos 20000/175679 registros...
# ✅ Inseridos 30000/175679 registros...
# ✅ Inseridos 40000/175679 registros...
# ✅ Inseridos 50000/175679 registros...
# ✅ Inseridos 60000/175679 registros...
# ✅ Inseridos 70000/175679 registros...
# ✅ Inseridos 80000/175679 registros...
# ✅ Inseridos 90000/175679 registros...
# ✅ Inseridos 100000/175679 registros...
# ✅ Inseridos 110000/175679 registros...
# ✅ Inseridos 120000/175679 registros...
# ✅ Inseridos 130000/175679 registros...
# ✅ Inseridos 140000/175679 registros...
# ✅ Inseridos 150000/175679 registros...
# ✅ Inseridos 160000/175679 registros...
# ✅ Inseridos 170000/175679 registros...
# ✅ Inseridos 175679/175679 registros...
# ✅ Registros inseridos com sucesso!

# %%
# Chamar a função para carregar a tabela do PostgreSQL
df_itens_licitacao_postgree = ler_tabela_postgresql("item", DB_HOST, DB_PORT, DB_NAME, DB_USER, DB_PASS)

# Exibir as 5 primeiras linhas
df_itens_licitacao_postgree.head()
# Out:
# ✅ Tabela 'item' carregada com sucesso! 175679 registros encontrados.
#    id  licitacao_id             item_codigo  \
# 0   1             1  1300940500001202300001
# 1   2             1  1300940500001202300002
# 2   3             2  1350080700001202300001
# 3   4             3  1350200700001202300001
# 4   5             3  1350200700001202300002
#
#                                       item_descricao  item_qtde  item_valor  \
# 0                                 SERVICO ENGENHARIA          1    99500.00
# 1                                 SERVICO ENGENHARIA          1    71112.00
# 2  MANUTENCAO DE SOFTWARE (CORRETIVA, PREVENTIVA,...          1    26636.45
# 3                                 FILTRO LABORATÓRIO          7    26674.20
# 4                                 FILTRO LABORATÓRIO         14    50587.60
#
#     vencedor_cnpj
# 0  24426491000103
# 1  24426491000103
# 2  05837045000139
# 3  07700042000184
# 4  07700042000184

# %% [markdown]
# ---
# ### 3.8) ETL PARTICIPANTE
# ---

# %%
df_participantes.head()
# Out:
#    numero  codigo_ug                                      nome_ug  \
# 0   12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 1   12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 2   12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 3   12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 4   12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
#
#    modalidade_codigo modalidade_desc       num_processo  orgao_codigo  \
# 0                  5          Pregão  21030.002858/2023         22000
# 1                  5          Pregão  21030.002858/2023         22000
# 2                  5          Pregão  21030.002858/2023         22000
# 3                  5          Pregão  21030.002858/2023         22000
# 4                  5          Pregão  21030.002858/2023         22000
#
#                                     orgao_nome             item_codigo  \
# 0  Ministério da Agricultura e Pecuária - Unid  1300940500001202300001
# 1  Ministério da Agricultura e Pecuária - Unid  1300940500001202300001
# 2  Ministério da Agricultura e Pecuária - Unid  1300940500001202300001
# 3  Ministério da Agricultura e Pecuária - Unid  1300940500001202300001
# 4  Ministério da Agricultura e Pecuária - Unid  1300940500001202300001
#
#        item_descricao     cnpj_codigo  \
# 0  SERVICO ENGENHARIA  35230250000100
# 1  SERVICO ENGENHARIA  08311793000171
# 2  SERVICO ENGENHARIA  23274187000117
# 3  SERVICO ENGENHARIA  14986916000177
# 4  SERVICO ENGENHARIA  05210095000191
#
#                                            cnpj_nome vencedor_flag   ano mes
# 0       CLEDENIR ALVES DA SILVA - SERVICOS ELETRICOS           NÃO  2024  01
# 1                            PLENNUS ENGENHARIA LTDA           NÃO  2024  01
# 2                              TEMPORY SERVICOS LTDA           NÃO  2024  01
# 3                   CORDEL AUTOMACAO & SERVICOS LTDA           NÃO  2024  01
# 4  PRESCOM - COMERCIO E SERVICOS DE CONSTRUCAO CI...           NÃO  2024  01

# %%
df_participantes['item_codigo'] = df_participantes.apply(lambda row: (
    f"{str(row['codigo_ug']).zfill(6)}"
    f"{str(row['modalidade_codigo']).zfill(2)}"
    f"{str(row['numero']).zfill(5)}"
    f"{str(row['ano']).zfill(4)}"
    f"99999"
) if pd.isnull(row['item_codigo']) or len(str(row['item_codigo'])) != 22 else row['item_codigo'], axis=1)

# %%
df_participantes.head()
# Out:
#    numero  codigo_ug                                      nome_ug  \
# 0   12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 1   12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 2   12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 3   12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 4   12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
#
#    modalidade_codigo modalidade_desc       num_processo  orgao_codigo  \
# 0                  5          Pregão  21030.002858/2023         22000
# 1                  5          Pregão  21030.002858/2023         22000
# 2                  5          Pregão  21030.002858/2023         22000
# 3                  5          Pregão  21030.002858/2023         22000
# 4                  5          Pregão  21030.002858/2023         22000
#
#                                     orgao_nome             item_codigo  \
# 0  Ministério da Agricultura e Pecuária - Unid  1300940500001202300001
# 1  Ministério da Agricultura e Pecuária - Unid  1300940500001202300001
# 2  Ministério da Agricultura e Pecuária - Unid  1300940500001202300001
# 3  Ministério da Agricultura e Pecuária - Unid  1300940500001202300001
# 4  Ministério da Agricultura e Pecuária - Unid  1300940500001202300001
#
#        item_descricao     cnpj_codigo  \
# 0  SERVICO ENGENHARIA  35230250000100
# 1  SERVICO ENGENHARIA  08311793000171
# 2  SERVICO ENGENHARIA  23274187000117
# 3  SERVICO ENGENHARIA  14986916000177
# 4  SERVICO ENGENHARIA  05210095000191
#
#                                            cnpj_nome vencedor_flag   ano mes
# 0       CLEDENIR ALVES DA SILVA - SERVICOS ELETRICOS           NÃO  2024  01
# 1                            PLENNUS ENGENHARIA LTDA           NÃO  2024  01
# 2                              TEMPORY SERVICOS LTDA           NÃO  2024  01
# 3                   CORDEL AUTOMACAO & SERVICOS LTDA           NÃO  2024  01
# 4  PRESCOM - COMERCIO E SERVICOS DE CONSTRUCAO CI...           NÃO  2024  01

# %%
df_participantes.shape
# Out:
# (508814, 15)

# %%
# Fazer o merge para verificar se o vencedor_cnpj está em df_participantes para o mesmo item_codigo
df_participantes_carga = df_participantes.merge(
    df_itens_licitacao_postgree[["id", "item_codigo", "vencedor_cnpj"]],  # Apenas colunas necessárias
    left_on=["item_codigo", "cnpj_codigo"],  # Correspondência entre item e vencedor
    right_on=["item_codigo", "vencedor_cnpj"],  # Correspondência entre item e participante
    how="left",
    indicator=True  # Adiciona uma coluna para verificar correspondências
)

# Renomear a coluna 'id' para 'item_id'
df_participantes_carga.rename(columns={"id": "item_id"}, inplace=True)

# Exibir o DataFrame atualizado
df_participantes_carga.head(5)
# Out:
#    numero  codigo_ug                                      nome_ug  \
# 0   12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 1   12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 2   12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 3   12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 4   12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
#
#    modalidade_codigo modalidade_desc       num_processo  orgao_codigo  \
# 0                  5          Pregão  21030.002858/2023         22000
# 1                  5          Pregão  21030.002858/2023         22000
# 2                  5          Pregão  21030.002858/2023         22000
# 3                  5          Pregão  21030.002858/2023         22000
# 4                  5          Pregão  21030.002858/2023         22000
#
#                                     orgao_nome             item_codigo  \
# 0  Ministério da Agricultura e Pecuária - Unid  1300940500001202300001
# 1  Ministério da Agricultura e Pecuária - Unid  1300940500001202300001
# 2  Ministério da Agricultura e Pecuária - Unid  1300940500001202300001
# 3  Ministério da Agricultura e Pecuária - Unid  1300940500001202300001
# 4  Ministério da Agricultura e Pecuária - Unid  1300940500001202300001
#
#        item_descricao     cnpj_codigo  \
# 0  SERVICO ENGENHARIA  35230250000100
# 1  SERVICO ENGENHARIA  08311793000171
# 2  SERVICO ENGENHARIA  23274187000117
# 3  SERVICO ENGENHARIA  14986916000177
# 4  SERVICO ENGENHARIA  05210095000191
#
#                                            cnpj_nome vencedor_flag   ano mes  \
# 0       CLEDENIR ALVES DA SILVA - SERVICOS ELETRICOS           NÃO  2024  01
# 1                            PLENNUS ENGENHARIA LTDA           NÃO  2024  01
# 2                              TEMPORY SERVICOS LTDA           NÃO  2024  01
# 3                   CORDEL AUTOMACAO & SERVICOS LTDA           NÃO  2024  01
# 4  PRESCOM - COMERCIO E SERVICOS DE CONSTRUCAO CI...           NÃO  2024  01
#
#    item_id vencedor_cnpj     _merge
# 0      NaN           NaN  left_only
# 1      NaN           NaN  left_only
# 2      NaN           NaN  left_only
# 3      NaN           NaN  left_only
# 4      NaN           NaN  left_only

# %%
df_participantes_carga.shape
# Out:
# (508814, 18)

# %%
df_participantes_carga['vencedor_flag'] = df_participantes_carga['vencedor_flag'].astype(str).str[0]
df_participantes_carga = df_participantes_carga[['item_id', 'cnpj_codigo', 'vencedor_flag' ]]

# %%
df_participantes_carga.head()
# Out:
#    item_id     cnpj_codigo vencedor_flag
# 0      NaN  35230250000100             N
# 1      NaN  08311793000171             N
# 2      NaN  23274187000117             N
# 3      NaN  14986916000177             N
# 4      NaN  05210095000191             N

# %%
# Insere dados de cnpj
resultado = inserir_dados_postgresql(df_participantes_carga, "participante", DB_HOST, DB_PORT, DB_NAME, DB_USER, DB_PASS, excluir_antes=True)

# Exibindo o resultado
print(resultado)
# Out:
# 🗑️ Todos os registros da tabela 'participante' foram excluídos.
# 📊 Total de registros a serem inseridos: 508814
# ✅ Inseridos 10000/508814 registros...
# ✅ Inseridos 20000/508814 registros...
# ✅ Inseridos 30000/508814 registros...
# ✅ Inseridos 40000/508814 registros...
# ✅ Inseridos 50000/508814 registros...
# ✅ Inseridos 60000/508814 registros...
# ✅ Inseridos 70000/508814 registros...
# ✅ Inseridos 80000/508814 registros...
# ✅ Inseridos 90000/508814 registros...
# ✅ Inseridos 100000/508814 registros...
# ✅ Inseridos 110000/508814 registros...
# ✅ Inseridos 120000/508814 registros...
# ✅ Inseridos 130000/508814 registros...
# ✅ Inseridos 140000/508814 registros...
# ✅ Inseridos 150000/508814 registros...
# ✅ Inseridos 160000/508814 registros...
# ✅ Inseridos 170000/508814 registros...
# ✅ Inseridos 180000/508814 registros...
# ✅ Inseridos 190000/508814 registros...
# ✅ Inseridos 200000/508814 registros...
# ✅ Inseridos 210000/508814 registros...
# ✅ Inseridos 220000/508814 registros...
# ✅ Inseridos 230000/508814 registros...
# ✅ Inseridos 240000/508814 registros...
# ✅ Inseridos 250000/508814 registros...
# ✅ Inseridos 260000/508814 registros...
# ✅ Inseridos 270000/508814 registros...
# ✅ Inseridos 280000/508814 registros...
# ✅ Inseridos 290000/508814 registros...
# ✅ Inseridos 300000/508814 registros...
# ✅ Inseridos 310000/508814 registros...
# ✅ Inseridos 320000/508814 registros...
# ✅ Inseridos 330000/508814 registros...
# ✅ Inseridos 340000/508814 registros...
# ✅ Inseridos 350000/508814 registros...
# ✅ Inseridos 360000/508814 registros...
# ✅ Inseridos 370000/508814 registros...
# ✅ Inseridos 380000/508814 registros...
# ✅ Inseridos 390000/508814 registros...
# ✅ Inseridos 400000/508814 registros...
# ✅ Inseridos 410000/508814 registros...
# ✅ Inseridos 420000/508814 registros...
# ✅ Inseridos 430000/508814 registros...
# ✅ Inseridos 440000/508814 registros...
# ✅ Inseridos 450000/508814 registros...
# ✅ Inseridos 460000/508814 registros...
# ✅ Inseridos 470000/508814 registros...
# ✅ Inseridos 480000/508814 registros...
# ✅ Inseridos 490000/508814 registros...
# ✅ Inseridos 500000/508814 registros...
# ✅ Inseridos 508814/508814 registros...
# ✅ Registros inseridos com sucesso!
